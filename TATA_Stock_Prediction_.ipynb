# %% [markdown]
# Stock Prices Prediction Using Long Term Short Memory

# %% [markdown]
# # Part 1 - Data Preprocessing

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset_train = pd.read_csv('NSE-TATAGLOBAL.csv')
training_set = dataset_train.iloc[:, 1:2].values

# %%
dataset_train
# Out:
#             Date    Open    High     Low    Last   Close  \
# 0     2018-09-28  234.05  235.95  230.20  233.50  233.75
# 1     2018-09-27  234.55  236.80  231.10  233.80  233.25
# 2     2018-09-26  240.00  240.00  232.50  235.00  234.25
# 3     2018-09-25  233.30  236.75  232.00  236.25  236.10
# 4     2018-09-24  233.55  239.20  230.75  234.00  233.30
# ...          ...     ...     ...     ...     ...     ...
# 2030  2010-07-27  117.60  119.50  112.00  118.80  118.65
# 2031  2010-07-26  120.10  121.00  117.10  117.10  117.60
# 2032  2010-07-23  121.80  121.95  120.25  120.35  120.65
# 2033  2010-07-22  120.30  122.00  120.25  120.75  120.90
# 2034  2010-07-21  122.10  123.00  121.05  121.10  121.55
#
#       Total Trade Quantity  Turnover (Lacs)
# 0                  3069914          7162.35
# 1                  5082859         11859.95
# 2                  2240909          5248.60
# 3                  2349368          5503.90
# 4                  3423509          7999.55
# ...                    ...              ...
# 2030                586100           694.98
# 2031                658440           780.01
# 2032                281312           340.31
# 2033                293312           355.17
# 2034                658666           803.56
#
# [2035 rows x 8 columns]

# %%
dataset_train.head()
# Out:
#          Date    Open    High     Low    Last   Close  Total Trade Quantity  \
# 0  2018-09-28  234.05  235.95  230.20  233.50  233.75               3069914
# 1  2018-09-27  234.55  236.80  231.10  233.80  233.25               5082859
# 2  2018-09-26  240.00  240.00  232.50  235.00  234.25               2240909
# 3  2018-09-25  233.30  236.75  232.00  236.25  236.10               2349368
# 4  2018-09-24  233.55  239.20  230.75  234.00  233.30               3423509
#
#    Turnover (Lacs)
# 0          7162.35
# 1         11859.95
# 2          5248.60
# 3          5503.90
# 4          7999.55

# %% [markdown]
# Feature Scaling

# %%
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler(feature_range = (0, 1))
training_set_scaled = sc.fit_transform(training_set)

# %%
X_train = []
y_train = []
for i in range(60, 2035):
    X_train.append(training_set_scaled[i-60:i, 0])
    y_train.append(training_set_scaled[i, 0])
X_train, y_train = np.array(X_train), np.array(y_train)

# %%
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

# %% [markdown]
# # Part 2 - Building the RNN

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout

# %%
regressor = Sequential()
regressor.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1], 1)))
regressor.add(Dropout(0.2))

# %%
regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))

# %%
regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))

# %%
regressor.add(LSTM(units = 50))
regressor.add(Dropout(0.2))

# %%
regressor.add(Dense(units = 1))
regressor.compile(optimizer = 'adam', loss = 'mean_squared_error')
regressor.fit(X_train, y_train, epochs = 100, batch_size = 32)
# Out:
# Epoch 1/100
# 62/62 [==============================] - 18s 154ms/step - loss: 0.0113
# Epoch 2/100
# 62/62 [==============================] - 15s 242ms/step - loss: 0.0029
# Epoch 3/100
# 62/62 [==============================] - 13s 210ms/step - loss: 0.0027
# Epoch 4/100
# 62/62 [==============================] - 7s 117ms/step - loss: 0.0026
# Epoch 5/100
# 62/62 [==============================] - 8s 133ms/step - loss: 0.0027
# Epoch 6/100
# 62/62 [==============================] - 8s 132ms/step - loss: 0.0025
# Epoch 7/100
# 62/62 [==============================] - 7s 113ms/step - loss: 0.0024
# Epoch 8/100
# 62/62 [==============================] - 8s 129ms/step - loss: 0.0020
# Epoch 9/100
# 62/62 [==============================] - 7s 114ms/step - loss: 0.0017
# Epoch 10/100
# 62/62 [==============================] - 8s 133ms/step - loss: 0.0024
# Epoch 11/100
# 62/62 [==============================] - 8s 134ms/step - loss: 0.0019
# Epoch 12/100
# 62/62 [==============================] - 7s 113ms/step - loss: 0.0020
# Epoch 13/100
# 62/62 [==============================] - 8s 130ms/step - loss: 0.0017
# Epoch 14/100
# 62/62 [==============================] - 7s 116ms/step - loss: 0.0018
# Epoch 15/100
# 62/62 [==============================] - 9s 139ms/step - loss: 0.0016
# Epoch 16/100
# 62/62 [==============================] - 8s 134ms/step - loss: 0.0016
# Epoch 17/100
# 62/62 [==============================] - 7s 116ms/step - loss: 0.0016
# Epoch 18/100
# 62/62 [==============================] - 8s 130ms/step - loss: 0.0017
# Epoch 19/100
# 62/62 [==============================] - 8s 126ms/step - loss: 0.0015
# Epoch 20/100
# 62/62 [==============================] - 8s 120ms/step - loss: 0.0015
# Epoch 21/100
# 62/62 [==============================] - 10s 155ms/step - loss: 0.0013
# Epoch 22/100
# 62/62 [==============================] - 8s 123ms/step - loss: 0.0014
# Epoch 23/100
# 62/62 [==============================] - 8s 122ms/step - loss: 0.0014
# Epoch 24/100
# 62/62 [==============================] - 8s 132ms/step - loss: 0.0012
# Epoch 25/100
# 62/62 [==============================] - 7s 113ms/step - loss: 0.0014
# Epoch 26/100
# 62/62 [==============================] - 8s 132ms/step - loss: 0.0012
# Epoch 27/100
# 62/62 [==============================] - 8s 126ms/step - loss: 0.0013
# Epoch 28/100
# 62/62 [==============================] - 7s 118ms/step - loss: 0.0012
# Epoch 29/100
# 62/62 [==============================] - 8s 128ms/step - loss: 0.0011
# Epoch 30/100
# 62/62 [==============================] - 7s 108ms/step - loss: 0.0011
# Epoch 31/100
# 62/62 [==============================] - 8s 131ms/step - loss: 0.0012
# Epoch 32/100
# 62/62 [==============================] - 8s 122ms/step - loss: 0.0012
# Epoch 33/100
# 62/62 [==============================] - 8s 122ms/step - loss: 0.0011
# Epoch 34/100
# 62/62 [==============================] - 8s 132ms/step - loss: 0.0011
# Epoch 35/100
# 62/62 [==============================] - 7s 110ms/step - loss: 9.2111e-04
# Epoch 36/100
# 62/62 [==============================] - 8s 131ms/step - loss: 0.0011
# Epoch 37/100
# 62/62 [==============================] - 8s 122ms/step - loss: 0.0010
# Epoch 38/100
# 62/62 [==============================] - 8s 122ms/step - loss: 0.0011
# Epoch 39/100
# 62/62 [==============================] - 8s 132ms/step - loss: 0.0010
# Epoch 40/100
# 62/62 [==============================] - 7s 115ms/step - loss: 8.4974e-04
# Epoch 41/100
# 62/62 [==============================] - 8s 132ms/step - loss: 9.4096e-04
# Epoch 42/100
# 62/62 [==============================] - 8s 131ms/step - loss: 9.7149e-04
# Epoch 43/100
# 62/62 [==============================] - 7s 115ms/step - loss: 0.0011
# Epoch 44/100
# 62/62 [==============================] - 8s 130ms/step - loss: 8.4997e-04
# Epoch 45/100
# 62/62 [==============================] - 7s 113ms/step - loss: 0.0011
# Epoch 46/100
# 62/62 [==============================] - 8s 130ms/step - loss: 0.0010
# Epoch 47/100
# 62/62 [==============================] - 8s 126ms/step - loss: 9.0812e-04
# Epoch 48/100
# 62/62 [==============================] - 7s 115ms/step - loss: 9.1633e-04
# Epoch 49/100
# 62/62 [==============================] - 8s 132ms/step - loss: 8.6674e-04
# Epoch 50/100
# 62/62 [==============================] - 7s 109ms/step - loss: 7.8281e-04
# Epoch 51/100
# 62/62 [==============================] - 8s 131ms/step - loss: 9.4966e-04
# Epoch 52/100
# 62/62 [==============================] - 8s 126ms/step - loss: 8.7165e-04
# Epoch 53/100
# 62/62 [==============================] - 7s 117ms/step - loss: 8.0864e-04
# Epoch 54/100
# 62/62 [==============================] - 8s 130ms/step - loss: 8.8615e-04
# Epoch 55/100
# 62/62 [==============================] - 7s 114ms/step - loss: 7.9909e-04
# Epoch 56/100
# 62/62 [==============================] - 8s 131ms/step - loss: 8.9140e-04
# Epoch 57/100
# 62/62 [==============================] - 8s 124ms/step - loss: 8.1214e-04
# Epoch 58/100
# 62/62 [==============================] - 7s 119ms/step - loss: 8.2285e-04
# Epoch 59/100
# 62/62 [==============================] - 8s 131ms/step - loss: 7.4812e-04
# Epoch 60/100
# 62/62 [==============================] - 7s 113ms/step - loss: 7.3832e-04
# Epoch 61/100
# 62/62 [==============================] - 8s 129ms/step - loss: 9.7751e-04
# Epoch 62/100
# 62/62 [==============================] - 8s 123ms/step - loss: 0.0010
# Epoch 63/100
# 62/62 [==============================] - 7s 119ms/step - loss: 7.2416e-04
# Epoch 64/100
# 62/62 [==============================] - 8s 133ms/step - loss: 8.8364e-04
# Epoch 65/100
# 62/62 [==============================] - 7s 112ms/step - loss: 8.1663e-04
# Epoch 66/100
# 62/62 [==============================] - 8s 130ms/step - loss: 6.8833e-04
# Epoch 67/100
# 62/62 [==============================] - 7s 120ms/step - loss: 8.2923e-04
# Epoch 68/100
# 62/62 [==============================] - 7s 120ms/step - loss: 7.5811e-04
# Epoch 69/100
# 62/62 [==============================] - 8s 131ms/step - loss: 9.3144e-04
# Epoch 70/100
# 62/62 [==============================] - 7s 116ms/step - loss: 7.9104e-04
# Epoch 71/100
# 62/62 [==============================] - 8s 134ms/step - loss: 7.5303e-04
# Epoch 72/100
# 62/62 [==============================] - 8s 131ms/step - loss: 6.9297e-04
# Epoch 73/100
# 62/62 [==============================] - 7s 112ms/step - loss: 7.6532e-04
# Epoch 74/100
# 62/62 [==============================] - 8s 133ms/step - loss: 7.6785e-04
# Epoch 75/100
# 62/62 [==============================] - 7s 109ms/step - loss: 7.4478e-04
# Epoch 76/100
# 62/62 [==============================] - 8s 134ms/step - loss: 6.7584e-04
# Epoch 77/100
# 62/62 [==============================] - 8s 131ms/step - loss: 6.9423e-04
# Epoch 78/100
# 62/62 [==============================] - 7s 113ms/step - loss: 6.6618e-04
# Epoch 79/100
# 62/62 [==============================] - 8s 130ms/step - loss: 6.2535e-04
# Epoch 80/100
# 62/62 [==============================] - 7s 112ms/step - loss: 6.3706e-04
# Epoch 81/100
# 62/62 [==============================] - 8s 128ms/step - loss: 6.5520e-04
# Epoch 82/100
# 62/62 [==============================] - 7s 119ms/step - loss: 6.1160e-04
# Epoch 83/100
# 62/62 [==============================] - 7s 119ms/step - loss: 6.1678e-04
# Epoch 84/100
# 62/62 [==============================] - 8s 131ms/step - loss: 6.7044e-04
# Epoch 85/100
# 62/62 [==============================] - 7s 111ms/step - loss: 7.7108e-04
# Epoch 86/100
# 62/62 [==============================] - 8s 129ms/step - loss: 6.7351e-04
# Epoch 87/100
# 62/62 [==============================] - 7s 115ms/step - loss: 6.3453e-04
# Epoch 88/100
# 62/62 [==============================] - 8s 122ms/step - loss: 6.3124e-04
# Epoch 89/100
# 62/62 [==============================] - 8s 129ms/step - loss: 7.3927e-04
# Epoch 90/100
# 62/62 [==============================] - 7s 110ms/step - loss: 7.6470e-04
# Epoch 91/100
# 62/62 [==============================] - 8s 130ms/step - loss: 7.0291e-04
# Epoch 92/100
# 62/62 [==============================] - 7s 108ms/step - loss: 5.9586e-04
# Epoch 93/100
# 62/62 [==============================] - 8s 129ms/step - loss: 7.5118e-04
# Epoch 94/100
# 62/62 [==============================] - 8s 128ms/step - loss: 6.3932e-04
# Epoch 95/100
# 62/62 [==============================] - 7s 111ms/step - loss: 5.8261e-04
# Epoch 96/100
# 62/62 [==============================] - 8s 125ms/step - loss: 6.9330e-04
# Epoch 97/100
# 62/62 [==============================] - 7s 113ms/step - loss: 5.4742e-04
# Epoch 98/100
# 62/62 [==============================] - 8s 129ms/step - loss: 8.5820e-04
# Epoch 99/100
# 62/62 [==============================] - 8s 128ms/step - loss: 7.5938e-04
# Epoch 100/100
# 62/62 [==============================] - 7s 114ms/step - loss: 6.8988e-04

# %% [markdown]
# # Part 3 - Making the predictions and visualising the results

# %%
dataset_test = pd.read_csv('tatatest.csv')
real_stock_price = dataset_test.iloc[:, 1:2].values

# %%
dataset_total = pd.concat((dataset_train['Open'], dataset_test['Open']), axis = 0)
inputs = dataset_total[len(dataset_total) - len(dataset_test) - 60:].values
inputs = inputs.reshape(-1,1)
inputs = sc.transform(inputs)
X_test = []
for i in range(60, 76):
    X_test.append(inputs[i-60:i, 0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
predicted_stock_price = regressor.predict(X_test)
predicted_stock_price = sc.inverse_transform(predicted_stock_price)
# Out:
# 1/1 [==============================] - 2s 2s/step

# %%
plt.plot(real_stock_price, color = 'blue', label = 'Real TATA Stock Price')
plt.plot(predicted_stock_price, color = 'purple', label = 'Predicted TAT Stock Price')
plt.title('TATA Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('TATA Stock Price')
plt.legend()
plt.show()

# %% [markdown]
# # THE END
